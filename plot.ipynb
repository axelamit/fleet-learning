# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np

# %%
with open("results/21-06-2023-08:37:10/history.pkl", "rb") as f:
    hist = pickle.load(f)

loss = [l[1] for l in hist.losses_centralized]
x = np.arange(len(loss))
plt.plot(x, loss)
plt.title("Fed loss")
plt.xlabel("Global round")
plt.ylabel("Loss")
plt.show()
print(loss)
# Out:
# [3326.641357421875, 1062.4420166015625, 569.24609375]

# %%
with open("results/21-06-2023-08:37:10/global_configs.pkl", "rb") as f:
    global_configs = pickle.load(f)

# %%
print(global_configs.NUM_CLIENTS)
# Out:
# 2
